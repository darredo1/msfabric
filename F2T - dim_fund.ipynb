# %%
df = spark.read.format("csv").option("header","true").load("Files/Alma Analytics/Fund Transactions/DIM - Fund.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Alma Analytics/Fund Transactions/DIM - Fund.csv".
display(df)
# Out:
# StatementMeta(, 23f3e4f0-f08e-4831-ba49-1d4d1112657a, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, d441badf-1c8d-4eda-8971-9ca83d25ad6f)

# %%
df_clean.write.format("delta").mode('overwrite').option("delta.columnMapping.mode", "name").saveAsTable("dim_fund")

df_clean.printSchema()
